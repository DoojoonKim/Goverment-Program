# %%
import pandas as pd
import numpy as np

# %%
# 데이터 로드
ori_df = pd.read_csv('./data/2016.csv', encoding='euc-kr')

# %%
ori_df.head(9)
# Out:
#    구분  죄종 발생검거      건수
# 0  중부  살인   발생     2.0
# 1  중부  살인   검거     2.0
# 2  중부  강도   발생     3.0
# 3  중부  강도   검거     3.0
# 4  중부  강간   발생   141.0
# 5  중부  강간   검거    96.0
# 6  중부  절도   발생  1204.0
# 7  중부  절도   검거   485.0
# 8  중부  폭력   발생  1335.0

# %%
ori_df.shape
# Out:
# (65534, 4)

# %%
# 피벗 테이블을 활용하여 데이터를 재구성한다.
tmp_df = pd.pivot_table(ori_df, 
                        columns=['죄종'],
                        index=['구분'], 
                        values=['건수'])

# %%
tmp_df.head(3)
# Out:
#        건수
# 죄종     강간    강도   살인      절도      폭력
# 구분
# 강남  304.0  25.0  3.0  1783.5  2216.0
# 강동  156.0  13.5  4.5  1328.0  2365.5
# 강북  188.0   4.5  6.5   947.0  2630.0

# %%
tmp_df
# 발생 검거가 기본 합산 후 평균으로 바뀌어서 원하는 형태가 되지 않았다.
# 발생과 검거는 데이터의 성격이 다르다.
# Out:
#         건수
# 죄종      강간    강도    살인      절도      폭력
# 구분
# 강남   304.0  25.0   3.0  1783.5  2216.0
# 강동   156.0  13.5   4.5  1328.0  2365.5
# 강북   188.0   4.5   6.5   947.0  2630.0
# 강서   257.0  10.0   9.5  1511.0  2986.0
# 관악   293.0  11.0   6.5  1520.0  2971.0
# 광진   256.5   8.5   4.0  1846.5  2201.5
# 구로   227.0  11.5   9.0  1385.5  2922.0
# 금천   159.0   7.0   6.0   959.0  2069.5
# 남대문   54.5   4.5   1.0   687.5   861.0
# 노원   150.5   7.5   5.5  1298.5  2320.0
# 도봉   122.0   5.0   3.0   679.0  1375.0
# 동대문  174.0  11.0   5.0  1505.5  2509.5
# 동작   237.0   7.0   7.0   890.0  1552.5
# 마포   359.5   5.5   4.0  1733.5  2719.5
# 방배    64.5   4.5   1.0   382.5   473.0
# 서대문  161.0   4.5   6.5  1127.5  1810.0
# 서부    51.5   3.0   4.0   585.0  1054.0
# 서초   285.0   7.0   4.0  1273.5  1710.5
# 성동    91.0   4.0   4.5  1096.0  1513.5
# 성북    89.0   3.0   2.0   585.5  1090.0
# 송파   209.0  13.5   8.5  1795.5  3048.5
# 수서   160.5  15.5   2.0   969.0  1548.5
# 양천   119.5   7.0   5.0  1237.0  2084.0
# 영등포  290.5  16.5  13.0  1640.5  3300.0
# 용산   232.5   9.5   4.0  1044.0  2196.0
# 은평    97.5   5.0   2.0   693.0  1432.0
# 종로   125.0   4.5   2.0   670.5  1213.0
# 종암    46.5   5.0   1.5   512.0   873.5
# 중랑   157.0  14.0   7.5  1371.5  2938.0
# 중부   118.5   3.0   2.0   844.5  1249.5
# 혜화    82.5   6.0   2.0   683.5   907.0

# %%
# 발생 검거 라는 컬럼의 데이터가 발생인놈만 모아서 사본을 받아서 피벗처리
df1 = ori_df[ori_df['발생검거']== '발생']
tmp_df1 = pd.pivot_table(df1, 
              index=['구분'],
              columns=['죄종'],
              values=['건수'])
newCol = {
    '강도':'강도발생',
    '살인':'살인발생',
    '절도':'절도발생',
    '폭력':'폭력발생'
}
tmp_df1.rename(columns=newCol, inplace=True)
tmp_df1.head(10)
# Out:
#         건수
# 죄종      강간  강도발생 살인발생    절도발생    폭력발생
# 구분
# 강남   339.0  24.0  3.0  2438.0  2336.0
# 강동   160.0  14.0  4.0  1754.0  2530.0
# 강북   217.0   5.0  7.0  1222.0  2778.0
# 강서   275.0  10.0  9.0  1952.0  3204.0
# 관악   322.0  12.0  6.0  2103.0  3235.0
# 광진   279.0  11.0  4.0  2636.0  2392.0
# 구로   273.0  10.0  9.0  1910.0  3164.0
# 금천   175.0   7.0  6.0  1264.0  2193.0
# 남대문   57.0   5.0  1.0   946.0   890.0
# 노원   159.0   6.0  5.0  1857.0  2516.0

# %%
# 발생 검거 라는 컬럼의 데이터가 검거인놈만 모아서 사본을 받아서 피벗처리
df2 = ori_df[ori_df['발생검거']== '검거']
tmp_df2 = pd.pivot_table(df2, 
              index=['구분'],
              columns=['죄종'],
              values=['건수'])
# newCol = {
#     '강간':'강간검거',
#     '강도':'강도검거',
#     '살인':'살인검거',
#     '절도':'절도검거',
#     '폭력':'폭력검거'
# }
# tmp_df2.rename(columns=newCol, inplace=True)
tmp_df2.head(10)
# Out:
#         건수
# 죄종      강간    강도    살인      절도      폭력
# 구분
# 강남   269.0  26.0   3.0  1129.0  2096.0
# 강동   152.0  13.0   5.0   902.0  2201.0
# 강북   159.0   4.0   6.0   672.0  2482.0
# 강서   239.0  10.0  10.0  1070.0  2768.0
# 관악   264.0  10.0   7.0   937.0  2707.0
# 광진   234.0   6.0   4.0  1057.0  2011.0
# 구로   181.0  13.0   9.0   861.0  2680.0
# 금천   143.0   7.0   6.0   654.0  1946.0
# 남대문   52.0   4.0   1.0   429.0   832.0
# 노원   142.0   9.0   6.0   740.0  2124.0

# %%
# 데이터 병합(tmp_df1, tmp_df2 병합을 한다.
# 행방향으로 병합
pd.merge(tmp_df1, tmp_df2, on='구분')
# 두개의 데이터가 같은 형태(shape)을 가지고 있다.
tmp = pd.concat([tmp_df1, tmp_df2], axis=1)
tmp
# Out:
#         건수
# 죄종      강간  강도발생  살인발생    절도발생    폭력발생     강간    강도    살인      절도      폭력
# 구분
# 강남   339.0  24.0   3.0  2438.0  2336.0  269.0  26.0   3.0  1129.0  2096.0
# 강동   160.0  14.0   4.0  1754.0  2530.0  152.0  13.0   5.0   902.0  2201.0
# 강북   217.0   5.0   7.0  1222.0  2778.0  159.0   4.0   6.0   672.0  2482.0
# 강서   275.0  10.0   9.0  1952.0  3204.0  239.0  10.0  10.0  1070.0  2768.0
# 관악   322.0  12.0   6.0  2103.0  3235.0  264.0  10.0   7.0   937.0  2707.0
# 광진   279.0  11.0   4.0  2636.0  2392.0  234.0   6.0   4.0  1057.0  2011.0
# 구로   273.0  10.0   9.0  1910.0  3164.0  181.0  13.0   9.0   861.0  2680.0
# 금천   175.0   7.0   6.0  1264.0  2193.0  143.0   7.0   6.0   654.0  1946.0
# 남대문   57.0   5.0   1.0   946.0   890.0   52.0   4.0   1.0   429.0   832.0
# 노원   159.0   6.0   5.0  1857.0  2516.0  142.0   9.0   6.0   740.0  2124.0
# 도봉   123.0   5.0   3.0   866.0  1441.0  121.0   5.0   3.0   492.0  1309.0
# 동대문  190.0  10.0   5.0  1940.0  2642.0  158.0  12.0   5.0  1071.0  2377.0
# 동작   325.0   7.0   8.0  1226.0  1661.0  149.0   7.0   6.0   554.0  1444.0
# 마포   399.0   4.0   4.0  2527.0  2939.0  320.0   7.0   4.0   940.0  2500.0
# 방배    78.0   4.0   1.0   472.0   500.0   51.0   5.0   1.0   293.0   446.0
# 서대문  175.0   5.0   6.0  1503.0  1976.0  147.0   4.0   7.0   752.0  1644.0
# 서부    54.0   4.0   4.0   781.0  1128.0   49.0   2.0   4.0   389.0   980.0
# 서초   350.0   9.0   4.0  1733.0  1838.0  220.0   5.0   4.0   814.0  1583.0
# 성동   104.0   3.0   4.0  1296.0  1619.0   78.0   5.0   5.0   896.0  1408.0
# 성북   103.0   3.0   2.0   790.0  1176.0   75.0   3.0   2.0   381.0  1004.0
# 송파   234.0  15.0   9.0  2543.0  3289.0  184.0  12.0   8.0  1048.0  2808.0
# 수서   177.0  15.0   2.0  1149.0  1666.0  144.0  16.0   2.0   789.0  1431.0
# 양천   131.0   7.0   5.0  1719.0  2250.0  108.0   7.0   5.0   755.0  1918.0
# 영등포  356.0  19.0  13.0  2341.0  3593.0  225.0  14.0  13.0   940.0  3007.0
# 용산   251.0   9.0   4.0  1489.0  2384.0  214.0  10.0   4.0   599.0  2008.0
# 은평   102.0   5.0   2.0   885.0  1536.0   93.0   5.0   2.0   501.0  1328.0
# 종로   137.0   6.0   4.0   952.0  1291.0  113.0   3.0   0.0   389.0  1135.0
# 종암    51.0   5.0   2.0   680.0   932.0   42.0   5.0   1.0   344.0   815.0
# 중랑   164.0  14.0   8.0  1691.0  3164.0  150.0  14.0   7.0  1052.0  2712.0
# 중부   141.0   3.0   2.0  1204.0  1335.0   96.0   3.0   2.0   485.0  1164.0
# 혜화   101.0   6.0   2.0   988.0   972.0   64.0   6.0   2.0   379.0   842.0

# %%
# pandas 데이터프레임의 값 파트 변경작업
tmp = tmp.astype(np.int)
tmp
# Out:
#       건수
# 죄종    강간 강도발생 살인발생  절도발생  폭력발생   강간  강도  살인    절도    폭력
# 구분
# 강남   339   24    3  2438  2336  269  26   3  1129  2096
# 강동   160   14    4  1754  2530  152  13   5   902  2201
# 강북   217    5    7  1222  2778  159   4   6   672  2482
# 강서   275   10    9  1952  3204  239  10  10  1070  2768
# 관악   322   12    6  2103  3235  264  10   7   937  2707
# 광진   279   11    4  2636  2392  234   6   4  1057  2011
# 구로   273   10    9  1910  3164  181  13   9   861  2680
# 금천   175    7    6  1264  2193  143   7   6   654  1946
# 남대문   57    5    1   946   890   52   4   1   429   832
# 노원   159    6    5  1857  2516  142   9   6   740  2124
# 도봉   123    5    3   866  1441  121   5   3   492  1309
# 동대문  190   10    5  1940  2642  158  12   5  1071  2377
# 동작   325    7    8  1226  1661  149   7   6   554  1444
# 마포   399    4    4  2527  2939  320   7   4   940  2500
# 방배    78    4    1   472   500   51   5   1   293   446
# 서대문  175    5    6  1503  1976  147   4   7   752  1644
# 서부    54    4    4   781  1128   49   2   4   389   980
# 서초   350    9    4  1733  1838  220   5   4   814  1583
# 성동   104    3    4  1296  1619   78   5   5   896  1408
# 성북   103    3    2   790  1176   75   3   2   381  1004
# 송파   234   15    9  2543  3289  184  12   8  1048  2808
# 수서   177   15    2  1149  1666  144  16   2   789  1431
# 양천   131    7    5  1719  2250  108   7   5   755  1918
# 영등포  356   19   13  2341  3593  225  14  13   940  3007
# 용산   251    9    4  1489  2384  214  10   4   599  2008
# 은평   102    5    2   885  1536   93   5   2   501  1328
# 종로   137    6    4   952  1291  113   3   0   389  1135
# 종암    51    5    2   680   932   42   5   1   344   815
# 중랑   164   14    8  1691  3164  150  14   7  1052  2712
# 중부   141    3    2  1204  1335   96   3   2   485  1164
# 혜화   101    6    2   988   972   64   6   2   379   842

# %%
#컬럼명 변경
#병합전에 수정 처리
newCol = {
    '강간':'강간검거',
    '강도':'강도검거',
    '살인':'살인검거',
    '절도':'절도검거',
    '폭력':'폭력검거'
}
tmp.rename(columns=newCol, inplace=True)

# %%
tmp.to_csv('./data/2016_start.csv', sep = ',' , encoding = 'euc-kr') # 최초가 euc-kr이다보니 저장 와중에 깨질수가 있다.

# %%
# 특정 행부터 데이터를 가져온다.
crime_per_police = pd.read_csv('./data/2016_start.csv', encoding = 'euc-kr', header=1)
crime_per_police.head(3)
#열 떨구기 del, 행 떨구기 drop (근데 방향 조정 가능)
crime_per_police.drop(axis = 1, index = [0], inplace=True)

# %%
# 특정 칼럼을 인덱스로 설정
crime_per_police.set_index('죄종', inplace = True)
crime_per_police.head(2)
# Out:
#      강간검거  강도발생  살인발생    절도발생    폭력발생  강간검거.1  강도검거  살인검거    절도검거    폭력검거
# 죄종
# 강남  339.0  24.0   3.0  2438.0  2336.0   269.0  26.0   3.0  1129.0  2096.0
# 강동  160.0  14.0   4.0  1754.0  2530.0   152.0  13.0   5.0   902.0  2201.0

# %%
# 타입 보정
crime_per_police.astype(np.int32, inplace = True)
# Out:
#      강간검거  강도발생  살인발생  절도발생  폭력발생  강간검거.1  강도검거  살인검거  절도검거  폭력검거
# 죄종
# 강남    339    24     3  2438  2336     269    26     3  1129  2096
# 강동    160    14     4  1754  2530     152    13     5   902  2201
# 강북    217     5     7  1222  2778     159     4     6   672  2482
# 강서    275    10     9  1952  3204     239    10    10  1070  2768
# 관악    322    12     6  2103  3235     264    10     7   937  2707
# 광진    279    11     4  2636  2392     234     6     4  1057  2011
# 구로    273    10     9  1910  3164     181    13     9   861  2680
# 금천    175     7     6  1264  2193     143     7     6   654  1946
# 남대문    57     5     1   946   890      52     4     1   429   832
# 노원    159     6     5  1857  2516     142     9     6   740  2124
# 도봉    123     5     3   866  1441     121     5     3   492  1309
# 동대문   190    10     5  1940  2642     158    12     5  1071  2377
# 동작    325     7     8  1226  1661     149     7     6   554  1444
# 마포    399     4     4  2527  2939     320     7     4   940  2500
# 방배     78     4     1   472   500      51     5     1   293   446
# 서대문   175     5     6  1503  1976     147     4     7   752  1644
# 서부     54     4     4   781  1128      49     2     4   389   980
# 서초    350     9     4  1733  1838     220     5     4   814  1583
# 성동    104     3     4  1296  1619      78     5     5   896  1408
# 성북    103     3     2   790  1176      75     3     2   381  1004
# 송파    234    15     9  2543  3289     184    12     8  1048  2808
# 수서    177    15     2  1149  1666     144    16     2   789  1431
# 양천    131     7     5  1719  2250     108     7     5   755  1918
# 영등포   356    19    13  2341  3593     225    14    13   940  3007
# 용산    251     9     4  1489  2384     214    10     4   599  2008
# 은평    102     5     2   885  1536      93     5     2   501  1328
# 종로    137     6     4   952  1291     113     3     0   389  1135
# 종암     51     5     2   680   932      42     5     1   344   815
# 중랑    164    14     8  1691  3164     150    14     7  1052  2712
# 중부    141     3     2  1204  1335      96     3     2   485  1164
# 혜화    101     6     2   988   972      64     6     2   379   842

# %%
# 주소 (-) gps 값, 지형지물명(-) 주소 및 위치정보 획득 : 지오코더(geocoder)
# kakao API 사용 => 계정 등록 => 앱생성 => 인증키 발급(restful key)
# dev.kakao.com

# 저장의 형태를 좀 더 조정하거나, 아니면 데이터를 읽을 때 조정하거나 해서 2015와 같은 형식 필요

# %%
# API를 이용한 http 통신을 통해서 획득
# requests, urllib,beautifulsoup, selenium 등등이 웹 크롤링 기술 대상 모듈
import requests
url = '''https://dapi.kakao.com/v2/local/search/keyword.json?query={0}&category_group_code=PO3
'''.format('서울 중부 경찰서')
KAKAO_API_KEY = 'f9bcade751569c67742c3c82a2e2f2af'
headers = {
    'Authorization':'KakaoAK {0}'.format(KAKAO_API_KEY)
}
res = requests.get(url, headers=headers)

# %%
res = res.json()
res
# Out:
# {'documents': [{'address_name': '서울 중구 저동2가 62-1',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서',
#    'distance': '',
#    'id': '11151738',
#    'phone': '182',
#    'place_name': '서울중부경찰서',
#    'place_url': 'http://place.map.daum.net/11151738',
#    'road_address_name': '서울 중구 수표로 27',
#    'x': '126.98959193048435',
#    'y': '37.563620722687844'},
#   {'address_name': '서울 중구 을지로3가 291-50',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 파출소',
#    'distance': '',
#    'id': '21268201',
#    'phone': '02-2266-2404',
#    'place_name': '서울중부경찰서 을지로3가파출소',
#    'place_url': 'http://place.map.daum.net/21268201',
#    'road_address_name': '서울 중구 충무로 56-1',
#    'x': '126.99286493571154',
#    'y': '37.56620864804315'},
#   {'address_name': '서울 중구 을지로5가 72-1',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 지구대',
#    'distance': '',
#    'id': '8528186',
#    'phone': '02-2279-1908',
#    'place_name': '서울중부경찰서 을지지구대',
#    'place_url': 'http://place.map.daum.net/8528186',
#    'road_address_name': '서울 중구 을지로 234',
#    'x': '127.00393932989843',
#    'y': '37.56650806865062'},
#   {'address_name': '서울 중구 장충동2가 197-34',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 파출소',
#    'distance': '',
#    'id': '8050461',
#    'phone': '',
#    'place_name': '서울중부경찰서 장충파출소',
#    'place_url': 'http://place.map.daum.net/8050461',
#    'road_address_name': '서울 중구 동호로 261',
#    'x': '127.00480828177658',
#    'y': '37.55875233220571'},
#   {'address_name': '서울 중구 약수동 844-3',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 지구대',
#    'distance': '',
#    'id': '9111102',
#    'phone': '02-2234-8112',
#    'place_name': '서울중부경찰서 약수지구대',
#    'place_url': 'http://place.map.daum.net/9111102',
#    'road_address_name': '서울 중구 동호로5길 15',
#    'x': '127.0123811614773',
#    'y': '37.55217464886805'},
#   {'address_name': '서울 중구 신당동 100-1',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 파출소',
#    'distance': '',
#    'id': '21268204',
#    'phone': '',
#    'place_name': '서울중부경찰서 신당파출소',
#    'place_url': 'http://place.map.daum.net/21268204',
#    'road_address_name': '서울 중구 다산로 248',
#    'x': '127.01638984949119',
#    'y': '37.565051159146165'},
#   {'address_name': '서울 중구 신당동 250-10',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 지구대',
#    'distance': '',
#    'id': '10487492',
#    'phone': '',
#    'place_name': '서울중부경찰서 광희지구대',
#    'place_url': 'http://place.map.daum.net/10487492',
#    'road_address_name': '서울 중구 퇴계로 375-1',
#    'x': '127.01340174502059',
#    'y': '37.565249715229605'},
#   {'address_name': '서울 중구 저동2가 62-1',
#    'category_group_code': 'PO3',
#    'category_group_name': '공공기관',
#    'category_name': '사회,공공기관 > 행정기관 > 경찰서',
#    'distance': '',
#    'id': '10795753',
#    'phone': '',
#    'place_name': '중부경찰서 민원봉사실',
#    'place_url': 'http://place.map.daum.net/10795753',
#    'road_address_name': '서울 중구 수표로 27',
#    'x': '126.99002655182646',
#    'y': '37.563674825136786'}],
#  'meta': {'is_end': True,
#   'pageable_count': 8,
#   'same_name': {'keyword': '서울 중부 경찰서', 'region': [], 'selected_region': ''},
#   'total_count': 8}}

# %%
res['documents'][0]
# Out:
# {'address_name': '서울 중구 저동2가 62-1',
#  'category_group_code': 'PO3',
#  'category_group_name': '공공기관',
#  'category_name': '사회,공공기관 > 행정기관 > 경찰서',
#  'distance': '',
#  'id': '11151738',
#  'phone': '182',
#  'place_name': '서울중부경찰서',
#  'place_url': 'http://place.map.daum.net/11151738',
#  'road_address_name': '서울 중구 수표로 27',
#  'x': '126.98959193048435',
#  'y': '37.563620722687844'}

# %%
print(res['documents'][0]['address_name'],
res['documents'][0]['y'],
res['documents'][0]['x'],
res['documents'][0]['place_name'])
# Out:
# 서울 중구 저동2가 62-1 37.563620722687844 126.98959193048435 서울중부경찰서

# %% [markdown]
# ### 범죄 통계 데이터에서 관할서에 대한 정보 추출
# - 반복작업을 통해 kakao API를 활용하여 주소,위도,경도등 획득

# %%
# 반복해서 관할서의 이름을 완성하여 출력(print)하시오.
crime_per_police.index
# Out:
# Index(['강남', '강동', '강북', '강서', '관악', '광진', '구로', '금천', '남대문', '노원', '도봉',
#        '동대문', '동작', '마포', '방배', '서대문', '서부', '서초', '성동', '성북', '송파', '수서',
#        '양천', '영등포', '용산', '은평', '종로', '종암', '중랑', '중부', '혜화'],
#       dtype='object', name='죄종')

# %%
# 검색어를 던져서 응답 데이터중에 주소, 위도, 경도, 질의어 리턴 함수
def netGetGeocoder(query):    
    url = '''https://dapi.kakao.com/v2/local/search/keyword.json?query={0}&category_group_code=PO3
    '''.format(query)
    KAKAO_API_KEY = 'f9bcade751569c67742c3c82a2e2f2af'
    headers = {
        'Authorization':'KakaoAK {0}'.format(KAKAO_API_KEY)
    }    
    #API 쿼리 수행
    res = requests.get(url, headers=headers)
    res = res.json()
    # 데이터 추출 : 주소, 위도, 경도, 질의어 순으로 튜플 형태로 리턴
    return res['documents'][0]['address_name'],res['documents'][0]['y'],res['documents'][0]['x'],res['documents'][0]['place_name']

# %%
# 반복해서 관할서의 이름을 완성하여 출력(print)하시오.
# 진행율
from tqdm import tqdm_notebook

#데이터를 담는 자료형

police_station_info = []

#경찰서 이름 개수만큼 반복
for name in tqdm_notebook(crime_per_police.index):
    #검색어 획득
    query  = '서울 %s 경찰서'%name
    
    police_station_info.append(netGetGeocoder(query))
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))

# %%
print(police_station_info)
# Out:
# [('서울 강남구 대치동 998', '37.50938856957773', '127.06707150521913', '서울강남경찰서'), ('서울 강동구 성내동 541-1', '37.528675586086614', '127.12689445192979', '서울강동경찰서'), ('서울 강북구 번동 415-15', '37.63740904254407', '127.02733964805316', '강북경찰서'), ('서울 양천구 신월동 25', '37.539782668110185', '126.82998362436423', '서울강서경찰서 임시청사'), ('서울 관악구 봉천동 1695-5', '37.474588550832955', '126.95106042259249', '서울관악경찰서'), ('서울 광진구 구의동 254-32', '37.5428121811901', '127.08384292223185', '서울광진경찰서'), ('서울 구로구 구로동 436', '37.49488449504183', '126.8866584714525', '서울구로경찰서'), ('서울 관악구 신림동 544', '37.48141868421242', '126.9099695798393', '서울금천경찰서'), ('서울 중구 남대문로5가 561', '37.55497931115527', '126.97350028716411', '서울남대문경찰서'), ('서울 노원구 하계동 250', '37.6423345266253', '127.071404832413', '서울노원경찰서'), ('서울 도봉구 창동 17', '37.65339850283973', '127.05270640425917', '서울도봉경찰서'), ('서울 동대문구 청량리동 229', '37.58508176321097', '127.04576239696928', '서울동대문경찰서'), ('서울 동작구 노량진동 72-35', '37.513147550556226', '126.94285899341229', '서울동작경찰서'), ('서울 마포구 아현동 618-1', '37.55101229580099', '126.95394220726662', '서울마포경찰서'), ('서울 서초구 방배동 455-10', '37.48155944749938', '126.98300906928465', '서울방배경찰서(2022년예정)'), ('서울 서대문구 미근동 165', '37.56490283018693', '126.96679138866718', '서울서대문경찰서'), ('서울 은평구 대조동 2-9', '37.61288240068257', '126.92747714311908', '서울서부경찰서'), ('서울 서초구 서초동 1726-1', '37.495614213519424', '127.00528950116143', '서초경찰서'), ('서울 성동구 행당동 192-8', '37.561796153278124', '127.03647222445021', '서울성동경찰서'), ('서울 성북구 삼선동5가 301', '37.58977065462821', '127.01625436761046', '서울성북경찰서'), ('서울 송파구 가락동 9', '37.501976988845826', '127.12716193066983', '서울송파경찰서'), ('서울 강남구 개포동 14', '37.49349614550641', '127.07714424999398', '수서경찰서'), ('서울 양천구 신정동 321', '37.51655448877979', '126.86554089186782', '서울양천경찰서'), ('서울 영등포구 당산동3가 2-11', '37.52585217071908', '126.90094655076123', '서울영등포경찰서'), ('서울 용산구 원효로1가 12-12', '37.5411811395942', '126.967778896191', '서울용산경찰서'), ('서울 은평구 불광동 산 24', '37.62852372694348', '126.92863070648912', '서울은평경찰서'), ('서울 종로구 경운동 90-18', '37.57554203072626', '126.98489890358965', '서울종로경찰서'), ('서울 성북구 종암동 3-1260', '37.60209664507542', '127.0322331298805', '서울종암경찰서'), ('서울 중랑구 신내동 810', '37.618237310628686', '127.10454069232486', '서울중랑경찰서'), ('서울 중구 저동2가 62-1', '37.563620722687844', '126.98959193048435', '서울중부경찰서'), ('서울 종로구 인의동 48-57', '37.57189237089298', '126.99893618246821', '서울혜화경찰서')]

# %%
# 위도만 추출해서 리스트로 출력 -> df에 컬럼 삽입을 해야하므로
#리스트 내포
# addrs, lats , lngs, names, 
addrs = [element[0] for element in police_station_info]
lats = [element[1] for element in police_station_info]
lngs = [element[2] for element in police_station_info]
names = [element[3] for element in police_station_info]

# %%
crime_per_police.head(2)
# Out:
#      강간검거  강도발생  살인발생    절도발생    폭력발생  강간검거.1  강도검거  살인검거    절도검거    폭력검거
# 죄종
# 강남  339.0  24.0   3.0  2438.0  2336.0   269.0  26.0   3.0  1129.0  2096.0
# 강동  160.0  14.0   4.0  1754.0  2530.0   152.0  13.0   5.0   902.0  2201.0

# %%
# crime_per_police 정보에 자치구 정보가 없다. -> 자치구: XX구 데이터 추가 필요
# addrs -> 구를 획득 ->칼럼 추가.
# 
# tmp_gu = []
# for addr in addrs:
#     # 분해 
#     tmp_gu.append(addr.split()[1]))# default blank
#     #print(addr.split(' ')[1])        
#리스트 내포
tmp_gu = [addr.split()[1] for addr in addrs if addr]

# %%
crime_per_police['자치구'] = tmp_gu

# %%
crime_per_police.head(2)
# Out:
#      강간검거  강도발생  살인발생    절도발생    폭력발생  강간검거.1  강도검거  살인검거    절도검거    폭력검거  자치구
# 죄종
# 강남  339.0  24.0   3.0  2438.0  2336.0   269.0  26.0   3.0  1129.0  2096.0  강남구
# 강동  160.0  14.0   4.0  1754.0  2530.0   152.0  13.0   5.0   902.0  2201.0  강동구

# %%
# 키 역할을 담당할 자치구 컬럼의 unique 조사
len(crime_per_police['자치구'].unique())
crime_per_police['자치구'].unique()
# 주소에서 자치구를 추출하다 보니 실제 소속 자치구와 일치하지 않는 관할서가 있다. 
# 금천구가 존재하지만 금천 -> 관악구, 금천구로 대체
# Out:
# array(['강남구', '강동구', '강북구', '양천구', '관악구', '광진구', '구로구', '중구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서초구', '서대문구', '은평구', '성동구', '성북구',
#        '송파구', '영등포구', '용산구', '종로구', '중랑구'], dtype=object)

# %%
# 금천 -> 관악구 =>금천구 대체, 수행
crime_per_police.loc[crime_per_police.index=='금천','자치구'] = '금천구'

# 강서 -> 양천구 => 강서구 대체
crime_per_police.loc[crime_per_police.index=='강서','자치구'] = '강서구'

# %%
crime_per_police
# Out:
#       강간검거  강도발생  살인발생    절도발생    폭력발생  강간검거.1  강도검거  살인검거    절도검거    폭력검거  \
# 죄종
# 강남   339.0  24.0   3.0  2438.0  2336.0   269.0  26.0   3.0  1129.0  2096.0
# 강동   160.0  14.0   4.0  1754.0  2530.0   152.0  13.0   5.0   902.0  2201.0
# 강북   217.0   5.0   7.0  1222.0  2778.0   159.0   4.0   6.0   672.0  2482.0
# 강서   275.0  10.0   9.0  1952.0  3204.0   239.0  10.0  10.0  1070.0  2768.0
# 관악   322.0  12.0   6.0  2103.0  3235.0   264.0  10.0   7.0   937.0  2707.0
# 광진   279.0  11.0   4.0  2636.0  2392.0   234.0   6.0   4.0  1057.0  2011.0
# 구로   273.0  10.0   9.0  1910.0  3164.0   181.0  13.0   9.0   861.0  2680.0
# 금천   175.0   7.0   6.0  1264.0  2193.0   143.0   7.0   6.0   654.0  1946.0
# 남대문   57.0   5.0   1.0   946.0   890.0    52.0   4.0   1.0   429.0   832.0
# 노원   159.0   6.0   5.0  1857.0  2516.0   142.0   9.0   6.0   740.0  2124.0
# 도봉   123.0   5.0   3.0   866.0  1441.0   121.0   5.0   3.0   492.0  1309.0
# 동대문  190.0  10.0   5.0  1940.0  2642.0   158.0  12.0   5.0  1071.0  2377.0
# 동작   325.0   7.0   8.0  1226.0  1661.0   149.0   7.0   6.0   554.0  1444.0
# 마포   399.0   4.0   4.0  2527.0  2939.0   320.0   7.0   4.0   940.0  2500.0
# 방배    78.0   4.0   1.0   472.0   500.0    51.0   5.0   1.0   293.0   446.0
# 서대문  175.0   5.0   6.0  1503.0  1976.0   147.0   4.0   7.0   752.0  1644.0
# 서부    54.0   4.0   4.0   781.0  1128.0    49.0   2.0   4.0   389.0   980.0
# 서초   350.0   9.0   4.0  1733.0  1838.0   220.0   5.0   4.0   814.0  1583.0
# 성동   104.0   3.0   4.0  1296.0  1619.0    78.0   5.0   5.0   896.0  1408.0
# 성북   103.0   3.0   2.0   790.0  1176.0    75.0   3.0   2.0   381.0  1004.0
# 송파   234.0  15.0   9.0  2543.0  3289.0   184.0  12.0   8.0  1048.0  2808.0
# 수서   177.0  15.0   2.0  1149.0  1666.0   144.0  16.0   2.0   789.0  1431.0
# 양천   131.0   7.0   5.0  1719.0  2250.0   108.0   7.0   5.0   755.0  1918.0
# 영등포  356.0  19.0  13.0  2341.0  3593.0   225.0  14.0  13.0   940.0  3007.0
# 용산   251.0   9.0   4.0  1489.0  2384.0   214.0  10.0   4.0   599.0  2008.0
# 은평   102.0   5.0   2.0   885.0  1536.0    93.0   5.0   2.0   501.0  1328.0
# 종로   137.0   6.0   4.0   952.0  1291.0   113.0   3.0   0.0   389.0  1135.0
# 종암    51.0   5.0   2.0   680.0   932.0    42.0   5.0   1.0   344.0   815.0
# 중랑   164.0  14.0   8.0  1691.0  3164.0   150.0  14.0   7.0  1052.0  2712.0
# 중부   141.0   3.0   2.0  1204.0  1335.0    96.0   3.0   2.0   485.0  1164.0
# 혜화   101.0   6.0   2.0   988.0   972.0    64.0   6.0   2.0   379.0   842.0
#
#       자치구
# 죄종
# 강남    강남구
# 강동    강동구
# 강북    강북구
# 강서    강서구
# 관악    관악구
# 광진    광진구
# 구로    구로구
# 금천    금천구
# 남대문    중구
# 노원    노원구
# 도봉    도봉구
# 동대문  동대문구
# 동작    동작구
# 마포    마포구
# 방배    서초구
# 서대문  서대문구
# 서부    은평구
# 서초    서초구
# 성동    성동구
# 성북    성북구
# 송파    송파구
# 수서    강남구
# 양천    양천구
# 영등포  영등포구
# 용산    용산구
# 은평    은평구
# 종로    종로구
# 종암    성북구
# 중랑    중랑구
# 중부     중구
# 혜화    종로구

# %%
len(crime_per_police['자치구'].unique())
# Out:
# 25

# %%
# 데이터저장(crime_analysis_mid_save.csv)
crime_per_police.to_csv('./data/crime_analysis_mid_save.csv', sep = ',', encoding = 'euc-kr')

# %% [markdown]
# ### 피벗테이블 기능 학습

# %%
# 데이터 로드
crime_per_police_raw = pd.read_csv('./data/crime_analysis_mid_save.csv', encoding='euc-kr' )

# %%
crime_per_police_raw.head()  # 인덱스가 다시 컬럼으로 돌아옴(csv의 특성.)
# Out:
#    죄종   강간검거  강도발생  살인발생    절도발생    폭력발생  강간검거.1  강도검거  살인검거    절도검거    폭력검거  \
# 0  강남  339.0  24.0   3.0  2438.0  2336.0   269.0  26.0   3.0  1129.0  2096.0
# 1  강동  160.0  14.0   4.0  1754.0  2530.0   152.0  13.0   5.0   902.0  2201.0
# 2  강북  217.0   5.0   7.0  1222.0  2778.0   159.0   4.0   6.0   672.0  2482.0
# 3  강서  275.0  10.0   9.0  1952.0  3204.0   239.0  10.0  10.0  1070.0  2768.0
# 4  관악  322.0  12.0   6.0  2103.0  3235.0   264.0  10.0   7.0   937.0  2707.0
#
#    자치구
# 0  강남구
# 1  강동구
# 2  강북구
# 3  강서구
# 4  관악구

# %%
# 피벗 테이블을 이용하여 구별 관할서 데이터를 합산 (행이 총 25개가 나와야 한다.)
# 자치구 기준
crime_anal = crime_per_police_raw.pivot_table(index='자치구', aggfunc=np.sum)

# %%
len(crime_anal.index)
# Out:
# 25

# %%
crime_anal.head(2)  # 숫자만 집계 되므로 죄종 열은 날라갔다.
# Out:
#       강간검거  강간검거.1  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생
# 자치구
# 강남구  516.0   413.0  42.0  39.0   5.0   5.0  1918.0  3587.0  3527.0  4002.0
# 강동구  160.0   152.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0

# %%
# 검거율 = 검거/발생*100
# 5대 범죄에 대한 검거율을 각각 추가한다.
crime_anal['폭력검거율'] = crime_anal['폭력검거']/crime_anal['폭력발생']*100
crime_anal['절도검거율'] = crime_anal['절도검거']/crime_anal['절도발생']*100
crime_anal['살인검거율'] = crime_anal['살인검거']/crime_anal['살인발생']*100
crime_anal['강도검거율'] = crime_anal['강도검거']/crime_anal['강도발생']*100
crime_anal['강간검거율'] = crime_anal['강간검거.1']/crime_anal['강간검거']*100
# 검거 컬럼을 모두 제거

# %%
crime_anal.head()
# Out:
#       강간검거  강간검거.1  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생  \
# 자치구
# 강남구  516.0   413.0  42.0  39.0   5.0   5.0  1918.0  3587.0  3527.0  4002.0
# 강동구  160.0   152.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북구  217.0   159.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서구  275.0   239.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악구  322.0   264.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0
#
#          폭력검거율      절도검거율       살인검거율       강도검거율      강간검거율
# 자치구
# 강남구  88.130935  53.470867  100.000000  107.692308  80.038760
# 강동구  86.996047  51.425314  125.000000   92.857143  95.000000
# 강북구  89.344852  54.991817   85.714286   80.000000  73.271889
# 강서구  86.392010  54.815574  111.111111  100.000000  86.909091
# 관악구  83.678516  44.555397  116.666667   83.333333  81.987578

# %%
#검거 제거
del crime_anal['강간검거.1']
del crime_anal['강도검거']
del crime_anal['절도검거']
del crime_anal['살인검거']
del crime_anal['폭력검거']

# %%
crime_anal.head()
# Out:
#       강간검거  강도발생  살인발생    절도발생    폭력발생      폭력검거율      절도검거율       살인검거율  \
# 자치구
# 강남구  516.0  39.0   5.0  3587.0  4002.0  88.130935  53.470867  100.000000
# 강동구  160.0  14.0   4.0  1754.0  2530.0  86.996047  51.425314  125.000000
# 강북구  217.0   5.0   7.0  1222.0  2778.0  89.344852  54.991817   85.714286
# 강서구  275.0  10.0   9.0  1952.0  3204.0  86.392010  54.815574  111.111111
# 관악구  322.0  12.0   6.0  2103.0  3235.0  83.678516  44.555397  116.666667
#
#           강도검거율      강간검거율
# 자치구
# 강남구  107.692308  80.038760
# 강동구   92.857143  95.000000
# 강북구   80.000000  73.271889
# 강서구  100.000000  86.909091
# 관악구   83.333333  81.987578

# %%
crime_anal.rename(columns={'강간검거':'강간발생'}, inplace=True)  # 전에 뭔가 잘못함.

# %%
# 전년도 데이터가 실수(의도) 들어가 있어서 100을 초과하는 데이터 -> 100 일괄 정리
# 사건 발생 연도와 검거 년도가 달라서 나오는 오류일 수도 있다.
target_col = ['폭력검거율','절도검거율','살인검거율','강도검거율','강간검거율']
tmp = crime_anal[:] # crime_anal.copy()

#연습
for col in target_col:
    # 해당 컬럼의 값이 100이 넘으면  -> True 그행의 컬럼값을 100으로 바꿔라.
    tmp.loc[tmp[col]>100, col] = 100
tmp
# Out:
#        강간발생  강도발생  살인발생    절도발생    폭력발생      폭력검거율      절도검거율       살인검거율  \
# 자치구
# 강남구   516.0  39.0   5.0  3587.0  4002.0  88.130935  53.470867  100.000000
# 강동구   160.0  14.0   4.0  1754.0  2530.0  86.996047  51.425314  100.000000
# 강북구   217.0   5.0   7.0  1222.0  2778.0  89.344852  54.991817   85.714286
# 강서구   275.0  10.0   9.0  1952.0  3204.0  86.392010  54.815574  100.000000
# 관악구   322.0  12.0   6.0  2103.0  3235.0  83.678516  44.555397  100.000000
# 광진구   279.0  11.0   4.0  2636.0  2392.0  84.071906  40.098634  100.000000
# 구로구   273.0  10.0   9.0  1910.0  3164.0  84.702908  45.078534  100.000000
# 금천구   175.0   7.0   6.0  1264.0  2193.0  88.736890  51.740506  100.000000
# 노원구   159.0   6.0   5.0  1857.0  2516.0  84.419714  39.849219  100.000000
# 도봉구   123.0   5.0   3.0   866.0  1441.0  90.839695  56.812933  100.000000
# 동대문구  190.0  10.0   5.0  1940.0  2642.0  89.969720  55.206186  100.000000
# 동작구   325.0   7.0   8.0  1226.0  1661.0  86.935581  45.187602   75.000000
# 마포구   399.0   4.0   4.0  2527.0  2939.0  85.062947  37.198259  100.000000
# 서대문구  175.0   5.0   6.0  1503.0  1976.0  83.198381  50.033267  100.000000
# 서초구   428.0  13.0   5.0  2205.0  2338.0  86.783576  50.204082  100.000000
# 성동구   104.0   3.0   4.0  1296.0  1619.0  86.967264  69.135802  100.000000
# 성북구   154.0   8.0   4.0  1470.0  2108.0  86.290323  49.319728   75.000000
# 송파구   234.0  15.0   9.0  2543.0  3289.0  85.375494  41.211168   88.888889
# 양천구   131.0   7.0   5.0  1719.0  2250.0  85.244444  43.920884  100.000000
# 영등포구  356.0  19.0  13.0  2341.0  3593.0  83.690509  40.153780  100.000000
# 용산구   251.0   9.0   4.0  1489.0  2384.0  84.228188  40.228341  100.000000
# 은평구   156.0   9.0   6.0  1666.0  2664.0  86.636637  53.421369  100.000000
# 종로구   238.0  12.0   6.0  1940.0  2263.0  87.361909  39.587629   33.333333
# 중구    198.0   8.0   3.0  2150.0  2225.0  89.707865  42.511628  100.000000
# 중랑구   164.0  14.0   8.0  1691.0  3164.0  85.714286  62.211709   87.500000
#
#            강도검거율      강간검거율
# 자치구
# 강남구   100.000000  80.038760
# 강동구    92.857143  95.000000
# 강북구    80.000000  73.271889
# 강서구   100.000000  86.909091
# 관악구    83.333333  81.987578
# 광진구    54.545455  83.870968
# 구로구   100.000000  66.300366
# 금천구   100.000000  81.714286
# 노원구   100.000000  89.308176
# 도봉구   100.000000  98.373984
# 동대문구  100.000000  83.157895
# 동작구   100.000000  45.846154
# 마포구   100.000000  80.200501
# 서대문구   80.000000  84.000000
# 서초구    76.923077  63.317757
# 성동구   100.000000  75.000000
# 성북구   100.000000  75.974026
# 송파구    80.000000  78.632479
# 양천구   100.000000  82.442748
# 영등포구   73.684211  63.202247
# 용산구   100.000000  85.258964
# 은평구    77.777778  91.025641
# 종로구    75.000000  74.369748
# 중구     87.500000  74.747475
# 중랑구   100.000000  91.463415

# %%
for col in target_col:
    # 해당 컬럼의 값이 100이 넘으면  -> True 그행의 컬럼값을 100으로 바꿔라.
    crime_anal.loc[crime_anal[col]>100, col] = 100
crime_anal.head(20)
# Out:
#        강간발생  강도발생  살인발생    절도발생    폭력발생      폭력검거율      절도검거율       살인검거율  \
# 자치구
# 강남구   516.0  39.0   5.0  3587.0  4002.0  88.130935  53.470867  100.000000
# 강동구   160.0  14.0   4.0  1754.0  2530.0  86.996047  51.425314  100.000000
# 강북구   217.0   5.0   7.0  1222.0  2778.0  89.344852  54.991817   85.714286
# 강서구   275.0  10.0   9.0  1952.0  3204.0  86.392010  54.815574  100.000000
# 관악구   322.0  12.0   6.0  2103.0  3235.0  83.678516  44.555397  100.000000
# 광진구   279.0  11.0   4.0  2636.0  2392.0  84.071906  40.098634  100.000000
# 구로구   273.0  10.0   9.0  1910.0  3164.0  84.702908  45.078534  100.000000
# 금천구   175.0   7.0   6.0  1264.0  2193.0  88.736890  51.740506  100.000000
# 노원구   159.0   6.0   5.0  1857.0  2516.0  84.419714  39.849219  100.000000
# 도봉구   123.0   5.0   3.0   866.0  1441.0  90.839695  56.812933  100.000000
# 동대문구  190.0  10.0   5.0  1940.0  2642.0  89.969720  55.206186  100.000000
# 동작구   325.0   7.0   8.0  1226.0  1661.0  86.935581  45.187602   75.000000
# 마포구   399.0   4.0   4.0  2527.0  2939.0  85.062947  37.198259  100.000000
# 서대문구  175.0   5.0   6.0  1503.0  1976.0  83.198381  50.033267  100.000000
# 서초구   428.0  13.0   5.0  2205.0  2338.0  86.783576  50.204082  100.000000
# 성동구   104.0   3.0   4.0  1296.0  1619.0  86.967264  69.135802  100.000000
# 성북구   154.0   8.0   4.0  1470.0  2108.0  86.290323  49.319728   75.000000
# 송파구   234.0  15.0   9.0  2543.0  3289.0  85.375494  41.211168   88.888889
# 양천구   131.0   7.0   5.0  1719.0  2250.0  85.244444  43.920884  100.000000
# 영등포구  356.0  19.0  13.0  2341.0  3593.0  83.690509  40.153780  100.000000
#
#            강도검거율      강간검거율
# 자치구
# 강남구   100.000000  80.038760
# 강동구    92.857143  95.000000
# 강북구    80.000000  73.271889
# 강서구   100.000000  86.909091
# 관악구    83.333333  81.987578
# 광진구    54.545455  83.870968
# 구로구   100.000000  66.300366
# 금천구   100.000000  81.714286
# 노원구   100.000000  89.308176
# 도봉구   100.000000  98.373984
# 동대문구  100.000000  83.157895
# 동작구   100.000000  45.846154
# 마포구   100.000000  80.200501
# 서대문구   80.000000  84.000000
# 서초구    76.923077  63.317757
# 성동구   100.000000  75.000000
# 성북구   100.000000  75.974026
# 송파구    80.000000  78.632479
# 양천구   100.000000  82.442748
# 영등포구   73.684211  63.202247

# %%
# Out:
#         강간     강도     살인    절도    폭력
# 자치구
# 강남구   True  False  False  True  True
# 강동구   True  False  False  True  True
# 강북구   True  False  False  True  True
# 강서구   True  False  False  True  True
# 관악구   True  False  False  True  True
# 광진구   True  False  False  True  True
# 구로구   True  False  False  True  True
# 금천구   True  False  False  True  True
# 노원구   True  False  False  True  True
# 도봉구   True  False  False  True  True
# 동대문구  True  False  False  True  True
# 동작구   True  False  False  True  True
# 마포구   True  False  False  True  True
# 서대문구  True  False  False  True  True
# 서초구   True  False  False  True  True
# 성동구   True  False  False  True  True
# 성북구   True  False  False  True  True
# 송파구   True  False  False  True  True
# 양천구   True  False  False  True  True
# 영등포구  True  False  False  True  True
# 용산구   True  False  False  True  True
# 은평구   True  False  False  True  True
# 종로구   True  False  False  True  True
# 중구    True  False  False  True  True
# 중랑구   True  False  False  True  True

# %%
# 컬럼명 변경

crime_anal.rename(columns={'강간발생':'강간', '강도발생':'강도', '살인발생':'살인', '절도발생':'절도', 
                           '폭력발생':'폭력'}, inplace=True)

# %%
crime_anal.head()
# Out:
#         강간    강도   살인      절도      폭력      폭력검거율      절도검거율       살인검거율  \
# 자치구
# 강남구  516.0  39.0  5.0  3587.0  4002.0  88.130935  53.470867  100.000000
# 강동구  160.0  14.0  4.0  1754.0  2530.0  86.996047  51.425314  100.000000
# 강북구  217.0   5.0  7.0  1222.0  2778.0  89.344852  54.991817   85.714286
# 강서구  275.0  10.0  9.0  1952.0  3204.0  86.392010  54.815574  100.000000
# 관악구  322.0  12.0  6.0  2103.0  3235.0  83.678516  44.555397  100.000000
#
#           강도검거율      강간검거율
# 자치구
# 강남구  100.000000  80.038760
# 강동구   92.857143  95.000000
# 강북구   80.000000  73.271889
# 강서구  100.000000  86.909091
# 관악구   83.333333  81.987578

# %%
# 데이터 조정 작업
# 살인사건은 5,4 한자리수 // 절도,폭력 4자리수
# 숫자를 같은 범위에 두고 비교하는 것이 명확하고 직관적
# 최대값을 1로 두고 정규화를 진행(nomalize)  진행 ->종합적으로 비교

# %%
# 파이썬의 머신러닝 scikit-learn에 있는 전처리 도구를 사용 최대, 최소값을 활용 정규화
from sklearn import preprocessing

# %%
# 대상
# crime_anal.columns
col = ['강간', '강도', '살인', '절도', '폭력']
# 대상 컬럼의 데이터 획득
x = crime_anal[col].values
# 전처리 모듈의 최대, 최소 스캐너 함수
min_max_scalar = preprocessing.MinMaxScaler()
# min_max_scalar함수 사용 데이터 받음
x_scaled = min_max_scalar.fit_transform(x)# transform 안에는 원래 float가 들어가야하는데 이미 float임.
x_scaled
# Out:
# array([[1.        , 1.        , 0.2       , 1.        , 1.        ],
#        [0.13592233, 0.30555556, 0.1       , 0.32635061, 0.42522452],
#        [0.27427184, 0.05555556, 0.4       , 0.13083425, 0.52206169],
#        [0.41504854, 0.19444444, 0.6       , 0.39911797, 0.68840297],
#        [0.52912621, 0.25      , 0.3       , 0.45461227, 0.70050761],
#        [0.42475728, 0.22222222, 0.1       , 0.65049614, 0.37133932],
#        [0.41019417, 0.19444444, 0.6       , 0.38368247, 0.67278407],
#        [0.1723301 , 0.11111111, 0.3       , 0.14626975, 0.2936353 ],
#        [0.13349515, 0.08333333, 0.2       , 0.36420434, 0.41975791],
#        [0.0461165 , 0.05555556, 0.        , 0.        , 0.        ],
#        [0.20873786, 0.19444444, 0.2       , 0.39470783, 0.46895744],
#        [0.53640777, 0.11111111, 0.5       , 0.1323043 , 0.08590394],
#        [0.71601942, 0.02777778, 0.1       , 0.61043734, 0.58492776],
#        [0.1723301 , 0.05555556, 0.3       , 0.23410511, 0.20890277],
#        [0.78640777, 0.27777778, 0.2       , 0.49209849, 0.35025381],
#        [0.        , 0.        , 0.1       , 0.15803014, 0.0695041 ],
#        [0.12135922, 0.13888889, 0.1       , 0.22197721, 0.26044514],
#        [0.31553398, 0.33333333, 0.6       , 0.61631753, 0.72159313],
#        [0.06553398, 0.11111111, 0.2       , 0.31348769, 0.31589223],
#        [0.61165049, 0.44444444, 1.        , 0.54208012, 0.84029676],
#        [0.35679612, 0.16666667, 0.1       , 0.22895994, 0.36821554],
#        [0.12621359, 0.16666667, 0.3       , 0.29400956, 0.47754783],
#        [0.32524272, 0.25      , 0.3       , 0.39470783, 0.32096837],
#        [0.22815534, 0.13888889, 0.        , 0.47188534, 0.30613042],
#        [0.14563107, 0.30555556, 0.5       , 0.30319735, 0.67278407]])

# %%
# 데이터 프레임 생성
crime_anal_normal = pd.DataFrame(x_scaled,columns=col, index=crime_anal.index)
crime_anal_normal.head()
# Out:
#            강간        강도   살인        절도        폭력
# 자치구
# 강남구  1.000000  1.000000  0.2  1.000000  1.000000
# 강동구  0.135922  0.305556  0.1  0.326351  0.425225
# 강북구  0.274272  0.055556  0.4  0.130834  0.522062
# 강서구  0.415049  0.194444  0.6  0.399118  0.688403
# 관악구  0.529126  0.250000  0.3  0.454612  0.700508

# %%
# 컬럼 추가를 1개가 아닌 5개를 동시에 처리하는 표현
crime_anal_normal[target_col] = crime_anal[target_col]
crime_anal_normal.head()
# Out:
#            강간        강도   살인        절도        폭력      폭력검거율      절도검거율  \
# 자치구
# 강남구  1.000000  1.000000  0.2  1.000000  1.000000  88.130935  53.470867
# 강동구  0.135922  0.305556  0.1  0.326351  0.425225  86.996047  51.425314
# 강북구  0.274272  0.055556  0.4  0.130834  0.522062  89.344852  54.991817
# 강서구  0.415049  0.194444  0.6  0.399118  0.688403  86.392010  54.815574
# 관악구  0.529126  0.250000  0.3  0.454612  0.700508  83.678516  44.555397
#
#           살인검거율       강도검거율      강간검거율
# 자치구
# 강남구  100.000000  100.000000  80.038760
# 강동구  100.000000   92.857143  95.000000
# 강북구   85.714286   80.000000  73.271889
# 강서구  100.000000  100.000000  86.909091
# 관악구  100.000000   83.333333  81.987578

# %%
#단순비교를 위해 정규화를 한 것이 아니라 시각화를 위해서 normalization 한거임.

# %%
#step1의 결과를 가져오기
f = '../step1_pandas_basic_matplotlib_analysis_csv/data/s_cctv_pop.csv'
result_CCTV = pd.read_csv(f, encoding='utf-8', index_col='자치구')
result_CCTV.head(2)
# Out:
#      cctv 소계   최근 증가율(%)  최근 증가율3(%)     인구수     한국인   외국인    고령자     외국인비율  \
# 자치구
# 강남구     3238  150.619195  162.277027  551888  546952  4936  66011  0.894384
# 강동구     1010  166.490765  210.419727  437050  432749  4301  57680  0.984098
#
#          고령자비율    cctv비율           오차
# 자치구
# 강남구  11.960941  0.586713  1561.929921
# 강동구  13.197575  0.231095   541.597345

# %%
# result_CCTV의 데이터 중 소계와 인구수를 가져와서 crime_anal_normal에 CCTV, 인구수
# 라는 컬럼명으로 데이터를 추가 후 샘플로 상위 2개만 출력하시오.
cols_cctv = ['cctv 소계','인구수'] # CCTV, 인구수
cols_new = ['CCTV','인구수']
crime_anal_normal[cols_new] = result_CCTV[cols_cctv] #개인적으로 for문이 들어가는 연산이라고 생각한다.
crime_anal_normal.head(2)
# Out:
#            강간        강도   살인        절도        폭력      폭력검거율      절도검거율  살인검거율  \
# 자치구
# 강남구  1.000000  1.000000  0.2  1.000000  1.000000  88.130935  53.470867  100.0
# 강동구  0.135922  0.305556  0.1  0.326351  0.425225  86.996047  51.425314  100.0
#
#           강도검거율     강간검거율  CCTV     인구수
# 자치구
# 강남구  100.000000  80.03876  3238  551888
# 강동구   92.857143  95.00000  1010  437050

# %%
# crime_anal_normal와 result_CCTV 데이터의 순서가 일치했기 때문에 가능
# 구성은 같은데 순서가 다를 경우엔 merge or 정렬 후 처리

# 순서가 일치 하는지 확인하고 싶어서 양쪽이 모두 같은지 확인하는 간단한 방법이 혹시 있나?

# %%
# 발생건수 합산 -> 범죄 추가
# col을 사용
# 해당 컬럼의 값들을 획득 -> 행방향 합산값 ->컬럼 추가
crime_anal_normal['범죄'] = np.sum(crime_anal_normal[col], axis = 1)
crime_anal_normal.head(2)
# Out:
#            강간        강도   살인        절도        폭력      폭력검거율      절도검거율  살인검거율  \
# 자치구
# 강남구  1.000000  1.000000  0.2  1.000000  1.000000  88.130935  53.470867  100.0
# 강동구  0.135922  0.305556  0.1  0.326351  0.425225  86.996047  51.425314  100.0
#
#           강도검거율     강간검거율  CCTV     인구수        범죄
# 자치구
# 강남구  100.000000  80.03876  3238  551888  4.200000
# 강동구   92.857143  95.00000  1010  437050  1.293053

# %%
# 검거율 총계 => 컬럼명 : 검거율
col_ratio = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_anal_normal['검거율'] = np.sum(crime_anal_normal[col_ratio], axis = 1)

# %%
crime_anal_normal.head(10)
# Out:
#            강간        강도   살인        절도        폭력      폭력검거율      절도검거율  \
# 자치구
# 강남구  1.000000  1.000000  0.2  1.000000  1.000000  88.130935  53.470867
# 강동구  0.135922  0.305556  0.1  0.326351  0.425225  86.996047  51.425314
# 강북구  0.274272  0.055556  0.4  0.130834  0.522062  89.344852  54.991817
# 강서구  0.415049  0.194444  0.6  0.399118  0.688403  86.392010  54.815574
# 관악구  0.529126  0.250000  0.3  0.454612  0.700508  83.678516  44.555397
# 광진구  0.424757  0.222222  0.1  0.650496  0.371339  84.071906  40.098634
# 구로구  0.410194  0.194444  0.6  0.383682  0.672784  84.702908  45.078534
# 금천구  0.172330  0.111111  0.3  0.146270  0.293635  88.736890  51.740506
# 노원구  0.133495  0.083333  0.2  0.364204  0.419758  84.419714  39.849219
# 도봉구  0.046117  0.055556  0.0  0.000000  0.000000  90.839695  56.812933
#
#           살인검거율       강도검거율      강간검거율  CCTV     인구수        범죄         검거율
# 자치구
# 강남구  100.000000  100.000000  80.038760  3238  551888  4.200000  421.640561
# 강동구  100.000000   92.857143  95.000000  1010  437050  1.293053  426.278504
# 강북구   85.714286   80.000000  73.271889   831  326063  1.382723  383.322844
# 강서구  100.000000  100.000000  86.909091   911  606981  2.297014  428.116675
# 관악구  100.000000   83.333333  81.987578  2109  521960  2.234246  393.554824
# 광진구  100.000000   54.545455  83.870968   878  370519  1.768815  362.586963
# 구로구  100.000000  100.000000  66.300366  1884  440305  2.261105  396.081808
# 금천구  100.000000  100.000000  81.714286  1348  252752  1.023346  422.191682
# 노원구  100.000000  100.000000  89.308176  1566  553177  1.200791  413.577109
# 도봉구  100.000000  100.000000  98.373984   825  344096  0.101672  446.026611

# %% [markdown]
# ### 향상된 시각화 도구
# - seaborn
# - 칼라맵을 적극적 사용
# - pyplot.scatter의 확장 (데이터 간의 성질 비교, 이상 유무를 확인)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# 시각화 결과물을 주피터에 내장 시키기 위해 
# %matplotlib inline
# 한글처리 
import platform
from matplotlib import font_manager, rc
# 한글처리
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':    # 맥
    rc( 'font', family='AppleGothic' )
elif platform.system() == 'Windows': # 윈도우
    # 폰트 차후 확인
    fontPath = 'c:/Windows/Fonts/malgun.ttf'
    fontName = font_manager.FontProperties( fname=fontPath ).get_name()
    rc( 'font', family=fontName )
else:
    print('알수없는 시스템. 미적용')

# %%
# %matplotlib.inline
crime_anal_normal.columns
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
# 산점도를 그려서 변수간 관계성 확인
sns.pairplot(crime_anal_normal, vars=['절도', '폭력', '살인'], kind='reg', size=3)

# %%
sns.pairplot(crime_anal_normal, x_vars=['CCTV','인구수'], y_vars=['절도', '폭력', '살인'], kind='reg', size=3)
# plt.show()

# %%
# 100% 데이터 때문에 관계성 파악이 애매하다.
sns.pairplot(crime_anal_normal, x_vars=['CCTV','인구수'], y_vars=['강도검거율', '살인검거율'], kind='reg', size=3)
plt.show()

# %%
# 검거율의 최고값을 100이라고 한정하고 나머지 정렬
tmp_max = crime_anal_normal['검거율'].max(0)
crime_anal_normal['검거율'] = crime_anal_normal['검거율'] / tmp_max * 100

# %%
# 정렬해서 확인
crime_anal_nomal_sort=crime_anal_normal.sort_values(by='검거율', ascending=False)

# %%
target_col

# %%
# 검거 기준 정렬 : crime_anal_nomal_sort
plt.figure(figsize=(10,10))
sns.heatmap(crime_anal_nomal_sort[target_col],annot=True,fmt='f',linewidths=0.5,cmap='RdPu')
plt.title('범죄검거비율')
plt.show()

# %%
# 5대 범죄 발생 통계
col

# %%
# 범죄의 평균값
crime_anal_normal['범죄']=crime_anal_normal['범죄']/5
crime_anal_normal_sort = crime_anal_normal.sort_values(by='범죄',ascending=False)
crime_anal_normal_sort.head()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(crime_anal_normal_sort[col],annot=True,fmt='f',linewidths=0.5,cmap='RdPu')
plt.title('범죄 발생 비율표')
plt.show()

# %%
# 데이터 저장
crime_anal_normal.to_csv('./data/crime_mid.csv', sep=',', encoding='euc-kr')
crime_anal_normal_legacy = crime_anal_normal

# %% [markdown]
# ### 지도 시각화
# - folium
# - 시군구 gps 경계선 데이터 -> json형태 제공

# %%
import json
geo_json = './data/seoul_gu.json'
geo_seoul_gu = json.load(open(geo_json,encoding='utf-8'))
geo_seoul_gu

# %%
import folium

# 자치구별 표시 ->범죄 컬럼 기준 칼라맵 사용

# %%
crime_anal_normal = pd.read_csv('./data/crime_mid.csv',encoding='euc-kr')
crime_anal_normal.head()

# %%
map = folium.Map(location=[37.541583, 127.013806],zoom_start=10)
map.choropleth(geo_data=geo_seoul_gu, data=crime_anal_normal, 
               columns=['자치구','범죄'], 
               key_on='feature.id',
               fill_color='YlGn',
               legend_name='자치구별 범죄발생 비율')
map

# %%
crime_anal_normal.set_index('자치구',inplace=True)

# %%
map = folium.Map(location=[37.541583, 127.013806],zoom_start=10)
map.choropleth(geo_data=geo_seoul_gu, data=crime_anal_normal['범죄'], 
               columns=[crime_anal_normal.index, crime_anal_normal['범죄']],
               key_on='feature.id',
               fill_color='YlGn',
               legend_name='자치구별 범죄발생 비율'
              )
map

# %%
crime_anal_normal_legacy.index

# %%
crime_anal_normal.index

# %%
crime_anal_normal['범죄']

# %%
tmp_pop_crime_rate = crime_anal_normal['범죄']/crime_anal_normal['인구수'] * 1000000

map = folium.Map(location=[37.541583, 127.013806],zoom_start=10)
map.choropleth(geo_data=geo_seoul_gu, data=tmp_pop_crime_rate,
               columns=[crime_anal_normal.index, tmp_pop_crime_rate],
               key_on='feature.id',
               fill_color='PuRd',
               legend_name='자치구별 범죄발생 비율'
              )
map
# 강남구 영등포구, 종로구 3개구는 인구대비 범죄율이 높다.

# %%
map = folium.Map(location=[37.541583, 127.013806],zoom_start=10)
map.choropleth(geo_data=geo_seoul_gu, data=crime_anal_normal['검거율'], 
               columns=[crime_anal_normal.index, crime_anal_normal['검거율']],
               key_on='feature.id',
               fill_color='YlGn',
               legend_name='자치구별 범죄발생 비율'
              )
map

# %% [markdown]
# ### 관할서별 검거현황 + 자치구별 범죄현황

# %%
crime_per_police_raw.head(2)

# %%
crime_per_police_raw.rename(columns={'강간검거.1':'강간검거'}, inplace=True)

# %%
crime_per_police_raw['lat']=lats
crime_per_police_raw['lngs']=lngs

# %%
crime_per_police_raw.head(2)

# %%
# 관할서별 검거 현황
col = ['강간검거','강도검거','살인검거','절도검거','폭력검거']
tmp = crime_per_police_raw[col]/crime_per_police_raw[col].max()
crime_per_police_raw['검거'] = np.sum(tmp, axis=1)

# %%
crime_per_police_raw.head(2)

# %%
# 서울 지도에 관할서 마킹 
map = folium.Map(location=[37.541583, 127.013806], zoom_start=10)
#마커처리 

for idx in crime_per_police_raw.index:
    folium.Marker([float(crime_per_police_raw['lat'][idx]),float(crime_per_police_raw['lngs'][idx])], icon=folium.Icon(icon='cloud')).add_to(map)
map

# %%
# 서울 지도에 관할서 마킹 
map = folium.Map(location=[37.541583, 127.013806], zoom_start=10)
#마커처리 

for idx in crime_per_police_raw.index:
    folium.Marker([float(crime_per_police_raw['lat'][idx]),float(crime_per_police_raw['lngs'][idx])], popup='서울 %s 경찰서' % crime_per_police_raw['죄종'][idx] , icon=folium.Icon(icon='cloud')).add_to(map)
map

# %%
# 관할서별  현황
# 서울 지도에 관할서 마킹 
map = folium.Map(location=[37.541583, 127.013806], zoom_start=11)
#마커처리 

for idx in crime_per_police_raw.index:
    gps_list = [float(crime_per_police_raw['lat'][idx]),float(crime_per_police_raw['lngs'][idx])]
    folium.Marker(gps_list,
                  popup='서울 %s 경찰서' % crime_per_police_raw['죄종'][idx] , 
                  icon=folium.Icon(icon='cloud')).add_to(map)
    folium.CircleMarker(gps_list, radius=crime_per_police_raw['검거'][idx] *10 ,                         
                        color='blue',
                        fill_color='#333333').add_to(map)
    #  다각형 (3,4,6,8,... )
    folium.RegularPolygonMarker(gps_list, radius=crime_per_police_raw['검거'][idx] *10 , color='blue',
                        fill_color='#333333',number_of_sides=6).add_to(map)
map

# %%
# 관할서별  현황
# 서울 지도에 관할서 마킹 
map = folium.Map(location=[37.541583, 127.013806], zoom_start=11)
#마커처리 

# tmp_pop_crime_rate = crime_anal_normal['범죄']/crime_anal_normal['인구수'] * 1000000

map.choropleth(geo_data=geo_seoul_gu, data=crime_anal_normal['범죄'],
               columns=[crime_anal_normal.index, crime_anal_normal['범죄']],
               key_on='feature.id',
               fill_color='PuRd',
               legend_name='자치구별 범죄발생 비율'
              )

# 강남구 영등포구, 종로구 3개구는 인구대비 범죄율이 높다.


for idx in crime_per_police_raw.index:
    gps_list = [float(crime_per_police_raw['lat'][idx]),float(crime_per_police_raw['lngs'][idx])]
    folium.Marker(gps_list,
                  popup='서울 %s 경찰서' % crime_per_police_raw['죄종'][idx] , 
                  icon=folium.Icon(icon='cloud')).add_to(map)
    folium.CircleMarker(gps_list, radius=crime_per_police_raw['검거'][idx] *10 ,                         
                        color='blue',
                        fill_color='#333333').add_to(map)
#     #  다각형 (3,4,6,8,... )
#     folium.RegularPolygonMarker(gps_list, radius=crime_per_police_raw['검거'][idx] *10 , color='blue',
#                         fill_color='#333333',number_of_sides=6).add_to(map)
map

# %% [markdown]
# - 범죄율이 높을수록 붉은색을 띈다.
# - 검거율이 높을수록 원이 커짐
